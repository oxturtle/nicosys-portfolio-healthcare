# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.0 MB 4.4 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/10.0 MB 5.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.0 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/10.0 MB 6.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/10.0 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.0 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 6.5 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.6 MB 7.2 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.6 MB 7.7 MB/s eta 0:00:02
# ...

# %%
er_visits = pd.read_csv("../data/raw/er_visits.csv")

# %%
print(er_visits )
# Out:
#       visit_id  patient_id arrival_date arrival_day  arrival_hour  \
# 0            1         329   11/30/2025      Sunday            19
# 1            2         152     1/7/2025     Tuesday             2
# 2            3          10    11/2/2025      Sunday             5
# 3            4         283    8/17/2025      Sunday            14
# 4            5         333    2/19/2026    Thursday            22
# ...        ...         ...          ...         ...           ...
# 2995      2996          62     6/9/2026     Tuesday            23
# 2996      2997         372    4/15/2025     Tuesday            19
# 2997      2998         156    7/31/2025    Thursday            21
# 2998      2999          22    1/11/2026      Sunday            18
# 2999      3000         155    1/18/2026      Sunday            14
#
#      severity_level  wait_time_minutes  length_of_stay_hours admitted
# 0               Low                137                   4.7       No
# ...
